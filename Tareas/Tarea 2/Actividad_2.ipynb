# %% [markdown]
# Actividad 2.
# Analisis de sentimientos de un texto / comentarios
#
# Se utilizo una sentencia de juicio de divorcio incausado y la cual tuvo fallo procedente, es decir las personas se divorciaron.
#
# Ubicacion y datos de la sentencia: JUZGADO MIXTO DE LO CIVIL Y FAMILIAR DE PRIMERA INSTANCIA DEL DUODECIMO DISTRITO JUDICIAL
#
# Fecha de publicacion: 22/enero/2025
#
# Materia: Familiar Oral
#
# Expediente: INFORMACION SUPRIMIDA
#
# Fuente: https://www.pjenl.gob.mx/SentenciasPublicas/Modulos/Familiar.aspx

# %%
import pdfplumber

# Ruta al archivo PDF
pdf_path = "/Users/USER/Desktop/sentencia-divorcio.pdf"

# Extracción del texto
with pdfplumber.open(pdf_path) as pdf:
    full_text = ""
    for page in pdf.pages:
        full_text += page.extract_text()

# Imprimir el texto extraído
print(full_text[:500])  # Ver las primeros 500 caracteres
# Out:
# “2025 año del Bicentenario de la Constitucionalidad en Nuevo León”
# *OM060058754705*
# PODER JUDICIAL DEL
# ESTADO DE NUEVO LEÓN. OM060058754705
# COORDINACION DE GESTION JUDICIAL JUICIOS EN ESTADO DE SENTENCIA Y SENTENCIADOS
# DE LOS JUZGADOS DE JUICIO
# CIVIL Y FAMILIAR ORAL SE DICTA SENTENCIA DEFINITIVA
# DEL QUINTO DISTRITO JUDICIAL
# CADEREYTA JIMENEZ, N. L.
# 0007
# JUZGADO SEGUNDO DE JUICIO CIVIL Y FAMILIAR
# ORAL
# Cadereyta Jiménez, Nuevo León, a 15 quince de enero del año
# 2025 dos mil veinticinco.
# Se procede

# %%
import re

import nltk
from nltk.corpus import stopwords

# Lista de stop words en español
stop_words = set(stopwords.words('spanish')) 

# Función actualizada para limpiar texto y eliminar stop words
def clean_text(text):
    # Limpieza básica: eliminación de saltos de línea, números y caracteres especiales
    text = re.sub(r'\n+', ' ', text)  # Reemplaza saltos de línea por espacios
    text = re.sub(r'\*.*?\*', '', text)  # Elimina cadenas entre asteriscos
    text = re.sub(r'\d+', '', text)  # Elimina números
    text = re.sub(r'[^\w\s]', '', text)  # Elimina signos de puntuación
    
    # Tokenización: Divide el texto en palabras individuales
    words = text.split()
    
    # Elimina stop words
    filtered_words = [word for word in words if word.lower() not in stop_words]
    
    # Reconstruye el texto limpio
    return ' '.join(filtered_words)

# Se agregan mas palabras que se consideran stopwords para los textos juridicos
palabras_adicionales_juridicas = {'año','Bicentenario','Constitucionalidad','Nuevo León' ,
                                  'PODER JUDICIAL', 'NUEVO LEÓN', 'COORDINACION', 'GESTION JUDICIAL', 'JUICIOS' 'SENTENCIA' ,
                                  'SENTENCIADOS', 'JUZGADOS', 'JUICIO CIVIL', 'FAMILIAR ORAL', 'DICTA' 'SENTENCIA' ,
                                  'DEFINITIVA', 'QUINTO', 'DISTRITO JUDICIAL', 'CADEREYTA JIMENEZ', 'NL' 'JUZGADO SEGUNDO',
                                  'JUICIO CIVIL', 'FAMILIAR''ORAL', 'Cadereyta Jiménez', 'Nuevo León', 'quince', 'enero' ,
                                  'año dos mil veinticinco','acta', 'actas','Código','nuevo', 'oficiales', 'om', 'oral','león',
                                 'artículo', 'artículos','fracción','fecha','forma','así','civil',
                                 'resolución' ,'respecto' ,'segundo', 'sentencia' ,'sentenciados','código',
                                'además', 'asimismo', 'por', 'con', 'sobre', 'como', 'de', 'para', 'entre', 'ni', 
                                'y', 'o', 'a', 'ante', 'por lo tanto', 'sin embargo', 'el', 'la', 'los', 'las', 'su', 
                                'suyo', 'mi', 'este', 'esta', 'aquella', 'esos', 'aquel', 'uno', 'ningún', 'toda', 'alguno', 
                                'ninguna', 'ser', 'haber', 'tener', 'deber', 'poder', 'hacer', 'estar', 'quedar', 'estaré', 
                                'será', 'habría', 'tendría', 'cuando', 'si', 'mientras', 'hasta', 'antes', 'después', 'luego', 
                                'entonces', 'siempre', 'sentencia', 'proceso', 'acto', 'juicio', 'resolución', 'auto', 'diligencia', 
                                'actuación', 'audiencia', 'notificación', 'documento', 'resolutiva', 'debido a', 'en relación con', 
                                'por lo que', 'es decir', 'en cuanto a', 'respecto a', 'en virtud de', 
                                  'por lo que se refiere a', 'Procedimiento', 'JUZGADO', 'familiar', 'DERECHO', 
                                  'JUZGADO', 'JUDICIAL', 'procedimiento', 'presente', 'anterior', 'DISTRITO JUDICIAL', 'Registro',
                                 'judicial', 'Procedimientos', 'Registro', 'COORDINACION GESTION', 'parte', 'Bicentenario Constitucionalidad',
                                 'requisitos legales', 'registro', 'ex', 'procedimientos', 'juzgado', 'requisitos', 'partes', 'ley',
                                 'divorcio', 'matrimonio', 'cónyuges', 'solicitud', 'hijos', 'contendientes', 'menores', 'quinto', 
                                  'incausado', 'declara', 'juicios', 'edad', 'distrito', 'derecho', 'conforme', 'misma', 
                                  'definitiva', 'dispuesto', 'vía', 'prueba', 'juzgados', 'expediente', 'cadereyta', 'autoridad', 'demandada', 
                                  'legales', 'términos', 'caso', 'gestion', 'celebrado', 'coordinacion', 'dentro', 'documentos', 'orgánica',
                                 'bicentenario', 'bajo', 'dos', 'libro', 'personas', 'vez', 'jimenez', 'mismo', 'efecto', 'séptimo',
                                 'fe', 'día', 'diversos', 'podrá', 'dicta', 'cónyuge'}

# Agregar las palabras adicionales al conjunto de stop words
stop_words.update(palabras_adicionales_juridicas)

# Aplica la limpieza al texto extraído
cleaned_text_no_stopwords = clean_text(full_text)
print(cleaned_text_no_stopwords[:1000])  # Verifica el texto limpio sin stop words
# Out:
# Constitucionalidad N L Jiménez mil veinticinco procede pronunciar constancias conforman relativo promoviera actora Vistos escrito inicial certificaciones constancia relativa celebrada cuanto consta sumario convino debió verse Glosario Procesal Resultando accionante presentó anexó mencionados Admisión admitió Desahogo vista observa realizó llamamiento promueve desahogó tiempo vista ordenada manifestando conformidad demanda interpuesta razones expuso realizó asistiendo observan videograbación constancia respectiva obstante incitara reconciliación posible dado accionante insistió propósito divorciarse Véase contenido DVD expedienteconcretándose acuerdo consecuencias ordenándose dictar Considerando Competencia competente domicilio procreados encuentra jurisdicción territorial previsto XII V II Bis Planteamiento promueve acción solicita disolución cuestión jurídica resolver determinar existencia petición cumple específicamente previstos indica tema capítulo tercero titulo sexto Existencia c

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Inicializa el vectorizador
#vectorizer = TfidfVectorizer(max_features=100)  # Limita a 100 palabras más frecuentes
# Se reemplaza la parte de tomar las palabras mas frecuentes por recomendacion del profesor
# En su lugar se toman aquellas palabras que aparecen en menos del 5%
vectorizer = TfidfVectorizer(min_df=0.05)  # Considera palabras que aparecen en menos del 5% de los documentos
tfidf_matrix = vectorizer.fit_transform([cleaned_text_no_stopwords])

# Imprime las palabras clave y sus pesos
print("Palabras clave:", vectorizer.get_feature_names_out())
print("Matriz TF-IDF:", tfidf_matrix.toarray())
# Out:
# Palabras clave: ['acceso' 'accionante' 'acción' 'acorde' 'acreditada' 'acreditado'
#  'acreditar' 'acreedora' 'actora' 'actos' 'actuaciones' 'acudan' 'acuerdo'
#  'admisible' 'admisión' 'admitió' 'adscrita' 'advirtiéndose' 'ahora'
#  'alguna' 'alimenticia' 'alimentos' 'allegada' 'allegados' 'alternativos'
#  'ambos' 'analizada' 'anexos' 'anexó' 'anotaciones' 'antecede' 'antonio'
#  'aplicación' 'aprobación' 'asegurará' 'asistiendo' 'atendiendo' 'atento'
#  'aun' 'autentifica' 'autoriza' 'autos' 'autónomo' 'auxilio' 'bien'
#  'bienes' 'bis' 'blanca' 'boletín' 'cambiado' 'capacidad' 'capítulo'
#  'cargo' 'carácter' 'casos' 'cautelar' 'celebrada' 'celebraron'
#  'certificaciones' 'certificación' 'certificada' 'certificadas'
#  'circunstancias' 'citada' 'civiles' 'compensatoria' 'competencia'
#  'competente' 'comprobarlo' 'comprueba' 'comunes' 'comunicación'
#  'comunicarse' 'conciliación' 'condiciones' 'confidencial' 'conforman'
#  'conformidad' 'conoció' 'consecuencia' 'consecuencias' 'consentida'
#  'considerada' 'considerando' 'consta' 'constancia' 'constancias'
#  'constitucionalidad' 'constituye' 'contenido' 'contraer' 'contrajeron'
#  'contrato' 'controversias' 'convenio' 'convino' 'convivencia'
#  'coordinación' 'copia' 'copias' 'coronado' 'correspondiente'
#  'correspondientes' 'cotejada' 'cualquier' 'cuanto' 'cuerpo' 'cuestión'
#  'cuidado' 'cumple' 'cumplieron' 'cumplimiento' 'cumplir' 'cura'
#  'custodia' 'da' 'dado' 'datos' 'deberá' 'deberán' 'debido' 'debió'
#  'declaración' 'decretado' 'decretarse' 'dedicó' 'definitivamente' 'dejar'
#  'demanda' 'demostró' 'derechos' 'derivados' 'desahogo' 'desahogó'
#  'descendencia' 'descrita' 'determinación' 'determinar' 'deviene'
#  'devolución' 'dicho' 'dictar' 'digitalizados' 'dignamente' 'director'
#  'disolución' 'disposiciones' 'disuelve' 'diverso' 'división'
#  'divorciarse' 'documental' 'documentales' 'domicilio' 'doy' 'duró' 'dvd'
#  'días' 'efectos' 'efectuar' 'ejecución' 'ejecutoriada' 'ejercerlo'
#  'elección' 'electrónico' 'elemento' 'embargo' 'encuadrar' 'encuentra'
#  'encuentre' 'encuentren' 'ende' 'entera' 'envío' 'escrito' 'especial'
#  'específicamente' 'establecen' 'establecido' 'estarse' 'estudiando'
#  'exceder' 'exceptuados' 'exhorta' 'exhortación' 'exhortó' 'existe'
#  'existencia' 'existentes' 'expedidas' 'expedienteconcretándose'
#  'expedienteconformidad' 'expida' 'expresamente' 'expuso' 'extinción'
#  'falsa' 'fijará' 'fijo' 'filiberto' 'firma' 'forzoso' 'frente' 'fuerza'
#  'fundamento' 'general' 'gestiones' 'gestión' 'glosario' 'gírese' 'hacen'
#  'haciendo' 'haga' 'hecho' 'hechos' 'hijas' 'hogar' 'hoy' 'hubieren'
#  'hágase' 'ii' 'incapaces' 'incidental' 'incitara' 'indica' 'información'
#  'inicial' 'innecesario' 'inscribe' 'inscritas' 'insistió' 'institución'
#  'inteligencia' 'interpretación' 'interpuesta' 'intervinientes' 'iv'
#  'jiménez' 'judiciales' 'juez' 'jurisdicción' 'jurídica' 'jurídicas'
#  'jurídico' 'juzgando' 'labores' 'legal' 'legalmente' 'libros'
#  'licenciada' 'licenciado' 'liquidación' 'llamamiento' 'lorena' 'lugar'
#  'lógico' 'manifestando' 'marginales' 'matrimonial' 'mayores' 'mecanismos'
#  'mediación' 'mediante' 'medida' 'medio' 'mencionados' 'mil' 'mismos'
#  'modificación' 'motiva' 'motivo' 'nacimiento' 'necesarias' 'necesario'
#  'normativos' 'notifíquese' 'numerales' 'número' 'obligaciones'
#  'obligación' 'obligados' 'obran' 'observa' 'observan' 'obstante'
#  'oficial' 'oficialías' 'oficio' 'oportunidad' 'orden' 'ordenada'
#  'ordenándose' 'original' 'originales' 'padres' 'pensión' 'perdurará'
#  'permita' 'personales' 'personalmente' 'petición' 'planteamiento'
#  'planteara' 'plena' 'plenamente' 'posesión' 'posible' 'precisados'
#  'preponderantemente' 'presentada' 'presentó' 'previo' 'previsto'
#  'previstos' 'probatorio' 'proceda' 'procede' 'procedencia' 'procedente'
#  'proceder' 'procesal' 'procreada' 'procreados' 'procrearon' 'procédase'
#  'promoviera' 'promueve' 'pronunciamiento' 'pronunciar' 'propuesta'
#  'propósito' 'protección' 'publicará' 'publicidad' 'publique' 'pudo'
#  'puede' 'pues' 'punto' 'pérez' 'pública' 'públicas' 'público'
#  'ratificada' 'razones' 'razón' 'realizar' 'realizó' 'recibir'
#  'reclamarse' 'recobran' 'reconciliación' 'redargüido' 'reiterando'
#  'relacionada' 'relación' 'relativa' 'relativas' 'relativo' 'remitirle'
#  'represente' 'residente' 'resolutivos' 'resolver' 'resolvió' 'respectiva'
#  'respectivas' 'resueltos' 'resultando' 'régimen' 'salvo' 'sancionarla'
#  'secretario' 'secretaría' 'según' 'sexto' 'señalados' 'señalar' 'sido'
#  'siendo' 'solicita' 'solo' 'solución' 'subsiste' 'subsistir' 'sujetos'
#  'sumario' 'suprimió' 'supuestos' 'surtirán' 'sustancialmente' 'tal'
#  'tales' 'tema' 'tercero' 'terceros' 'territorial' 'tiempo' 'titulo'
#  'tramitado' 'transparencia' 'trámite' 'término' 'unión' 'valor' 'vega'
#  'veinticinco' 'veinticuatro' 'verse' 'versión' 'videograbación'
#  'vinculante' 'virtud' 'vista' 'vistos' 'vivir' 'véase' 'vínculo' 'xii'
#  'ésta' 'éste' 'último' 'único']
# Matriz TF-IDF: [[0.03617873 0.07235746 0.07235746 0.03617873 0.03617873 0.03617873
#   0.03617873 0.03617873 0.07235746 0.03617873 0.03617873 0.03617873
#   0.03617873 0.03617873 0.03617873 0.07235746 0.03617873 0.03617873
#   0.03617873 0.07235746 0.03617873 0.10853619 0.03617873 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.03617873 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.03617873 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.03617873 0.07235746
#   0.03617873 0.03617873 0.07235746 0.07235746 0.03617873 0.03617873
#   0.03617873 0.03617873 0.03617873 0.07235746 0.03617873 0.03617873
#   0.03617873 0.07235746 0.07235746 0.03617873 0.10853619 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.07235746 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.07235746 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.03617873 0.07235746
#   0.03617873 0.03617873 0.10853619 0.03617873 0.03617873 0.03617873
#   0.07235746 0.07235746 0.07235746 0.10853619 0.03617873 0.07235746
#   0.03617873 0.03617873 0.03617873 0.03617873 0.10853619 0.03617873
#   0.03617873 0.03617873 0.07235746 0.03617873 0.03617873 0.07235746
#   0.03617873 0.03617873 0.07235746 0.03617873 0.03617873 0.07235746
#   0.03617873 0.10853619 0.03617873 0.07235746 0.03617873 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.07235746 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.03617873 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.07235746 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.03617873 0.03617873
#   0.03617873 0.07235746 0.03617873 0.03617873 0.03617873 0.03617873
#   0.03617873 0.10853619 0.03617873 0.03617873 0.03617873 0.10853619
#   0.07235746 0.03617873 0.07235746 0.03617873 0.07235746 0.03617873
#   0.07235746 0.03617873 0.10853619 0.03617873 0.07235746 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.03617873 0.03617873
#   0.07235746 0.03617873 0.03617873 0.03617873 0.03617873 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.07235746 0.07235746
#   0.03617873 0.03617873 0.03617873 0.03617873 0.03617873 0.03617873
#   0.03617873 0.10853619 0.03617873 0.03617873 0.03617873 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.03617873 0.03617873
#   0.03617873 0.03617873 0.07235746 0.03617873 0.03617873 0.03617873
#   0.03617873 0.07235746 0.03617873 0.03617873 0.03617873 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.03617873 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.07235746 0.03617873
#   0.07235746 0.03617873 0.07235746 0.07235746 0.03617873 0.03617873
#   0.03617873 0.03617873 0.07235746 0.03617873 0.03617873 0.03617873
#   0.03617873 0.07235746 0.03617873 0.03617873 0.03617873 0.07235746
#   0.03617873 0.03617873 0.07235746 0.03617873 0.03617873 0.07235746
#   0.03617873 0.03617873 0.03617873 0.03617873 0.03617873 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.03617873 0.03617873
#   0.07235746 0.07235746 0.03617873 0.03617873 0.07235746 0.03617873
#   0.07235746 0.03617873 0.07235746 0.07235746 0.03617873 0.03617873
#   0.03617873 0.07235746 0.03617873 0.03617873 0.03617873 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.03617873 0.03617873
#   0.03617873 0.03617873 0.03617873 0.07235746 0.03617873 0.03617873
#   0.07235746 0.03617873 0.03617873 0.03617873 0.03617873 0.03617873
#   0.03617873 0.10853619 0.03617873 0.03617873 0.03617873 0.03617873
#   0.07235746 0.03617873 0.03617873 0.07235746 0.03617873 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.03617873 0.03617873
#   0.07235746 0.07235746 0.03617873 0.03617873 0.03617873 0.03617873
#   0.07235746 0.03617873 0.03617873 0.03617873 0.03617873 0.03617873
#   0.07235746 0.03617873 0.07235746 0.03617873 0.03617873 0.07235746
#   0.07235746 0.03617873 0.03617873 0.03617873 0.03617873 0.03617873
#   0.03617873 0.07235746 0.03617873 0.03617873 0.07235746 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.03617873 0.07235746
#   0.03617873 0.03617873 0.03617873 0.07235746 0.03617873 0.03617873
#   0.03617873 0.10853619 0.03617873 0.03617873 0.03617873 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.03617873 0.03617873
#   0.03617873 0.03617873 0.03617873 0.07235746 0.07235746 0.03617873
#   0.03617873 0.03617873 0.07235746 0.07235746 0.03617873 0.03617873
#   0.07235746 0.03617873 0.03617873 0.03617873 0.07235746 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.03617873 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.07235746 0.03617873
#   0.03617873 0.07235746 0.07235746 0.03617873 0.03617873 0.07235746
#   0.03617873 0.03617873 0.03617873 0.03617873 0.03617873 0.03617873
#   0.03617873 0.03617873 0.03617873 0.03617873 0.07235746 0.07235746
#   0.03617873 0.03617873 0.10853619 0.03617873 0.03617873 0.03617873
#   0.03617873 0.03617873 0.03617873]]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Genera la nube de palabras quitando las palabras que son stopwords
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(cleaned_text_no_stopwords)

# Muestra la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Inicializa el vectorizador
#vectorizer = TfidfVectorizer(max_features=100)  # Limita a 100 palabras más frecuentes
# Se reemplaza la parte de tomar las palabras mas frecuentes por recomendacion del profesor
# En su lugar se toman aquellas palabras que aparecen en menos del 5%
vectorizer = TfidfVectorizer(min_df=0.05)  # Considera palabras que aparecen en menos del 5% de los documentos
tfidf_matrix = vectorizer.fit_transform([cleaned_text_no_stopwords])


# Obtén las palabras clave
top_words = vectorizer.get_feature_names_out()

# Imprime las palabras clave
print("Palabras clave:", top_words)
# Out:
# Palabras clave: ['acceso' 'accionante' 'acción' 'acorde' 'acreditada' 'acreditado'
#  'acreditar' 'acreedora' 'actora' 'actos' 'actuaciones' 'acudan' 'acuerdo'
#  'admisible' 'admisión' 'admitió' 'adscrita' 'advirtiéndose' 'ahora'
#  'alguna' 'alimenticia' 'alimentos' 'allegada' 'allegados' 'alternativos'
#  'ambos' 'analizada' 'anexos' 'anexó' 'anotaciones' 'antecede' 'antonio'
#  'aplicación' 'aprobación' 'asegurará' 'asistiendo' 'atendiendo' 'atento'
#  'aun' 'autentifica' 'autoriza' 'autos' 'autónomo' 'auxilio' 'bien'
#  'bienes' 'bis' 'blanca' 'boletín' 'cambiado' 'capacidad' 'capítulo'
#  'cargo' 'carácter' 'casos' 'cautelar' 'celebrada' 'celebraron'
#  'certificaciones' 'certificación' 'certificada' 'certificadas'
#  'circunstancias' 'citada' 'civiles' 'compensatoria' 'competencia'
#  'competente' 'comprobarlo' 'comprueba' 'comunes' 'comunicación'
#  'comunicarse' 'conciliación' 'condiciones' 'confidencial' 'conforman'
#  'conformidad' 'conoció' 'consecuencia' 'consecuencias' 'consentida'
#  'considerada' 'considerando' 'consta' 'constancia' 'constancias'
#  'constitucionalidad' 'constituye' 'contenido' 'contraer' 'contrajeron'
#  'contrato' 'controversias' 'convenio' 'convino' 'convivencia'
#  'coordinación' 'copia' 'copias' 'coronado' 'correspondiente'
#  'correspondientes' 'cotejada' 'cualquier' 'cuanto' 'cuerpo' 'cuestión'
#  'cuidado' 'cumple' 'cumplieron' 'cumplimiento' 'cumplir' 'cura'
#  'custodia' 'da' 'dado' 'datos' 'deberá' 'deberán' 'debido' 'debió'
#  'declaración' 'decretado' 'decretarse' 'dedicó' 'definitivamente' 'dejar'
#  'demanda' 'demostró' 'derechos' 'derivados' 'desahogo' 'desahogó'
#  'descendencia' 'descrita' 'determinación' 'determinar' 'deviene'
#  'devolución' 'dicho' 'dictar' 'digitalizados' 'dignamente' 'director'
#  'disolución' 'disposiciones' 'disuelve' 'diverso' 'división'
#  'divorciarse' 'documental' 'documentales' 'domicilio' 'doy' 'duró' 'dvd'
#  'días' 'efectos' 'efectuar' 'ejecución' 'ejecutoriada' 'ejercerlo'
#  'elección' 'electrónico' 'elemento' 'embargo' 'encuadrar' 'encuentra'
#  'encuentre' 'encuentren' 'ende' 'entera' 'envío' 'escrito' 'especial'
#  'específicamente' 'establecen' 'establecido' 'estarse' 'estudiando'
#  'exceder' 'exceptuados' 'exhorta' 'exhortación' 'exhortó' 'existe'
#  'existencia' 'existentes' 'expedidas' 'expedienteconcretándose'
#  'expedienteconformidad' 'expida' 'expresamente' 'expuso' 'extinción'
#  'falsa' 'fijará' 'fijo' 'filiberto' 'firma' 'forzoso' 'frente' 'fuerza'
#  'fundamento' 'general' 'gestiones' 'gestión' 'glosario' 'gírese' 'hacen'
#  'haciendo' 'haga' 'hecho' 'hechos' 'hijas' 'hogar' 'hoy' 'hubieren'
#  'hágase' 'ii' 'incapaces' 'incidental' 'incitara' 'indica' 'información'
#  'inicial' 'innecesario' 'inscribe' 'inscritas' 'insistió' 'institución'
#  'inteligencia' 'interpretación' 'interpuesta' 'intervinientes' 'iv'
#  'jiménez' 'judiciales' 'juez' 'jurisdicción' 'jurídica' 'jurídicas'
#  'jurídico' 'juzgando' 'labores' 'legal' 'legalmente' 'libros'
#  'licenciada' 'licenciado' 'liquidación' 'llamamiento' 'lorena' 'lugar'
#  'lógico' 'manifestando' 'marginales' 'matrimonial' 'mayores' 'mecanismos'
#  'mediación' 'mediante' 'medida' 'medio' 'mencionados' 'mil' 'mismos'
#  'modificación' 'motiva' 'motivo' 'nacimiento' 'necesarias' 'necesario'
#  'normativos' 'notifíquese' 'numerales' 'número' 'obligaciones'
#  'obligación' 'obligados' 'obran' 'observa' 'observan' 'obstante'
#  'oficial' 'oficialías' 'oficio' 'oportunidad' 'orden' 'ordenada'
#  'ordenándose' 'original' 'originales' 'padres' 'pensión' 'perdurará'
#  'permita' 'personales' 'personalmente' 'petición' 'planteamiento'
#  'planteara' 'plena' 'plenamente' 'posesión' 'posible' 'precisados'
#  'preponderantemente' 'presentada' 'presentó' 'previo' 'previsto'
#  'previstos' 'probatorio' 'proceda' 'procede' 'procedencia' 'procedente'
#  'proceder' 'procesal' 'procreada' 'procreados' 'procrearon' 'procédase'
#  'promoviera' 'promueve' 'pronunciamiento' 'pronunciar' 'propuesta'
#  'propósito' 'protección' 'publicará' 'publicidad' 'publique' 'pudo'
#  'puede' 'pues' 'punto' 'pérez' 'pública' 'públicas' 'público'
#  'ratificada' 'razones' 'razón' 'realizar' 'realizó' 'recibir'
#  'reclamarse' 'recobran' 'reconciliación' 'redargüido' 'reiterando'
#  'relacionada' 'relación' 'relativa' 'relativas' 'relativo' 'remitirle'
#  'represente' 'residente' 'resolutivos' 'resolver' 'resolvió' 'respectiva'
#  'respectivas' 'resueltos' 'resultando' 'régimen' 'salvo' 'sancionarla'
#  'secretario' 'secretaría' 'según' 'sexto' 'señalados' 'señalar' 'sido'
#  'siendo' 'solicita' 'solo' 'solución' 'subsiste' 'subsistir' 'sujetos'
#  'sumario' 'suprimió' 'supuestos' 'surtirán' 'sustancialmente' 'tal'
#  'tales' 'tema' 'tercero' 'terceros' 'territorial' 'tiempo' 'titulo'
#  'tramitado' 'transparencia' 'trámite' 'término' 'unión' 'valor' 'vega'
#  'veinticinco' 'veinticuatro' 'verse' 'versión' 'videograbación'
#  'vinculante' 'virtud' 'vista' 'vistos' 'vivir' 'véase' 'vínculo' 'xii'
#  'ésta' 'éste' 'último' 'único']

# %%
import matplotlib.pyplot as plt
import numpy as np

# Inicializa el vectorizador
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer2 = TfidfVectorizer(max_features=10)  # Limita a 10 palabras más frecuentes
tfidf_matrix2 = vectorizer2.fit_transform([cleaned_text_no_stopwords])

# Obtén las palabras clave y sus respectivos valores TF-IDF
top_words_10 = vectorizer2.get_feature_names_out()
top_tfidf_scores_10 = np.array(tfidf_matrix2.sum(axis=0)).flatten()

# Ordena las palabras por su puntaje TF-IDF
sorted_indices = np.argsort(top_tfidf_scores_10)[::-1]
top_words_sorted = top_words_10[sorted_indices]
top_scores_sorted = top_tfidf_scores_10[sorted_indices]

#  Grafica de barras
plt.figure(figsize=(10, 6))
plt.barh(top_words_sorted, top_scores_sorted, color='skyblue')
plt.xlabel('Puntaje TF-IDF')
plt.title('Top 10 Palabras Más Comunes')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# Una de la parte importante del analisis de la sentencia es saber eliminar las palabras que no sirven o no son utiles.  El tener identificado tambien las palabras que mas se repiten permite identificar que palabras podrian repetirse en todas las sentencias, tal es el caso de la palabra "sentencia", que esta es utilizada como titulo de cada pagina de la sentencia. De igual manera la palabra código, que hace referencia a la utilizacion del documento que contiene las leyes.

# %%
# Se agregan palabras dummy positivas / negativas para identificar si la sentencia es positiva o negativa.
positive_words = [
    "acreditada", "acreditado", "declaración", "conformidad", "cumple",
    "cumplimiento", "definitiva", "procedente",
    "legal", "autentifica", "reconocimiento", "competente",
    "mediación", "capacidad", "aprobación", "subsiste", "comprueba"
]

negative_words = [
    "rechazo", "incumplimiento",
    "problemático", "extinción", "alegación", "conflicto",
    "controversias", "incidental", "problemático", "inecesario", "motivo",
    "modificación", "pérdida", "argumentación", "alegaciones"
]

# %%
# Función para analizar el sentimiento
def sentiment_analysis_top_words(words, positive_lexicon, negative_lexicon):
    positive_count = sum(1 for word in words if word in positive_lexicon)
    negative_count = sum(1 for word in words if word in negative_lexicon)
    return positive_count, negative_count

# Aplicar la función a las palabras más frecuentes
positive_count, negative_count = sentiment_analysis_top_words(top_words, positive_words, negative_words)

# Resultado del analisis
print(f"Palabras positivas encontradas: {positive_count}")
print(f"Palabras negativas encontradas: {negative_count}")

# Determinar sentimiento general
if positive_count > negative_count:
    print("Sentimiento General: Positivo")
elif negative_count > positive_count:
    print("Sentimiento General: Negativo")
else:
    print("Sentimiento General: Neutro") # Si es empate es neutro.
# Out:
# Palabras positivas encontradas: 15
# Palabras negativas encontradas: 5
# Sentimiento General: Positivo

# %%
import matplotlib.pyplot as plt

# Datos que se utilizaran en la grafica Positivas - Negativas
categories = ['Positivas', 'Negativas']
counts = [positive_count, negative_count]

# Gráfico de barras
plt.bar(categories, counts, color=['#81C784', '#FF8A65'])
plt.title('Distribución de Sentimientos en las Palabras Más Frecuentes')
plt.ylabel('Cantidad de Palabras')
plt.yticks(range(0, int(max(counts)) + 1))  # Asegura que los números sean enteros

plt.show()
